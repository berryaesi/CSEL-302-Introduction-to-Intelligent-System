# %% [markdown]
# <a href="https://colab.research.google.com/github/berryaesi/CSEL-302-Introduction-to-Intelligent-System/blob/main/0227_Lesson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. Import Libraries**

# %%
import pandas as pd # Data Manipulation
import numpy as np #Numerical Operation
import matplotlib.pyplot as plt # Data Visualization
from sklearn.linear_model import LinearRegression #Data modeling

# %% [markdown]
# # **2. Generating Random Data**

# %%
num_points = 50

X = np.random.randint(0,100, num_points)
Y = 2 * X + np.random.normal(0, 10, num_points)

# %% [markdown]
# # **3. Create Dataframe and Saving to CSV**

# %%
data = pd.DataFrame({'X': X, 'Y': Y})

data.to_csv('TorresData.csv', index = False)
print(data.head())
# Out:
#     X           Y
# 0  84  191.833308
# 1  43   74.240423
# 2  50  103.942792
# 3  86  190.583617
# 4  65  134.852502

# %% [markdown]
# # **4. Viasualizing the Data**

# %%
plt.scatter(data['X'], data ['Y'])
plt.xlabel('Independent Variable (X)')
plt.ylabel ('Dependent Variable (Y)')
plt.title('Scatter Plot of Data')
plt.show()

# %% [markdown]
# # **5. Preparing Data for Modeling**

# %%
X = data[['X']] #Independent Variable
Y = data[['Y']] # Dependent variable

# %% [markdown]
# # **6. Fitting the Linear Regression Model**

# %%
model = LinearRegression()
model.fit(X,Y)
# Out:
# LinearRegression()

# %% [markdown]
# # **7. Getting Model Coefficients**

# %%
slope = model.coef_[0]

intercept = model.intercept_

print('Slope', slope)
print ('Intercept', intercept)

# %% [markdown]
# # **8. Visualizing the Linear Regression Line**

# %%
plt.scatter(X,Y)
plt.plot(X,model.predict(X), color='red')
plt.xlabel('Independent Variable (X)')
plt.ylabel ('Dependent Variable (Y)')
plt.title('Linear Regression')
plt.show()

# %% [markdown]
# # **9. Making Predictions**

# %%
new_X = [[np.random.randint(100,200)]]

predicted_Y = model.predict(new_X)

print('Value of X: ', new_X)
print('Predicted Value of Y: ', predicted_Y )
# Out:
# Value of X:  [[193]]
# Predicted Value of Y:  [[385.56843402]]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
